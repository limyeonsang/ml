# %% [markdown]
# <a href="https://colab.research.google.com/github/limyeonsang/ml_with_kaggle/blob/main/maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
fig = go.Figure(go.Scattergeo())
fig.update_layout(height=300, margin={"r":0, "t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4e79de83-c3e5-4d5e-bb3f-fb0f071859c7" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e79de83-c3e5-4d5e-bb3f-fb0f071859c7")) {
#                     Plotly.newPlot(
#                         '4e79de83-c3e5-4d5e-bb3f-fb0f071859c7',
#                         [{"type": "scattergeo"}],
# ...

# %%
fig = go.Figure(go.Scattergeo())
fig.update_geos(resolution=50, showcoastlines=True, coastlinecolor='RebeccaPurple', #땅과 바다 경계선
                showland=True, landcolor='LightGreen', #땅
                showocean=True, oceancolor='LightBlue', #바다
                showlakes=True, lakecolor='Blue', #호수
                showrivers=True, rivercolor='Blue', #강
                showcountries=True, countrycolor='red', #국경선
                lataxis_showgrid=True, lonaxis_showgrid=True) #배경 가로세로 선
fig.update_layout(height=300, margin={"r":0, "t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f0a2267e-7509-416f-90b6-814f57f9c725" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f0a2267e-7509-416f-90b6-814f57f9c725")) {
#                     Plotly.newPlot(
#                         'f0a2267e-7509-416f-90b6-814f57f9c725',
#                         [{"type": "scattergeo"}],
# ...

# %%
fig = go.Figure(go.Scattergeo())
fig.update_geos(projection_type='orthographic',
                showland=True, landcolor='green',
                 showocean=True, oceancolor='lightBlue')
fig.update_layout(height=300, margin={'r':0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d12a067e-6e26-4d8c-bdb8-49ab3d5c4713" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d12a067e-6e26-4d8c-bdb8-49ab3d5c4713")) {
#                     Plotly.newPlot(
#                         'd12a067e-6e26-4d8c-bdb8-49ab3d5c4713',
#                         [{"type": "scattergeo"}],
# ...

# %%
fig = go.Figure(go.Scattergeo())
fig.update_geos(center=dict(lon=-30, lat=-30),
    projection_rotation=dict(lon=30, lat=30, roll=30),
    lataxis_range=[-50,20], lonaxis_range=[0, 200]
)
fig.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb42ebdb-dc71-4694-9cb8-7332f0ec035f" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb42ebdb-dc71-4694-9cb8-7332f0ec035f")) {
#                     Plotly.newPlot(
#                         'bb42ebdb-dc71-4694-9cb8-7332f0ec035f',
#                         [{"type": "scattergeo"}],
# ...

# %%
fig = go.Figure(go.Scattergeo())
fig.update_geos(lataxis_showgrid=True, lonaxis_showgrid=True)
fig.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a13e5839-6f4a-4202-8bbb-eb5ebe161e43" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a13e5839-6f4a-4202-8bbb-eb5ebe161e43")) {
#                     Plotly.newPlot(
#                         'a13e5839-6f4a-4202-8bbb-eb5ebe161e43',
#                         [{"type": "scattergeo"}],
# ...
